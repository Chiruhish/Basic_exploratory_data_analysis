# %% [markdown]
# exploratory data analysis basics

# %%
import pandas as pd
import numpy as np 
import matplotlib.pylab as plt 
import seaborn as sns

# %%
plt.style.use('ggplot')

# %%
df=pd.read_csv(r"C:/Users/user/OneDrive\Desktop/lebron_career.csv")

# %%
df.shape
# Out:
# (1132, 26)

# %% [markdown]
# use shape .head()etc to initially look at the data and also list out the column
# because we might want to subse the column use dtypes to see what kind of data tyoe it is

# %%
df.columns
# Out:
# Index(['game', 'date', 'age', 'team', 'opp', 'result', 'mp', 'fg', 'fga',
#        'fgp', 'three', 'threeatt', 'threep', 'ft', 'fta', 'ftp', 'orb', 'drb',
#        'trb', 'ast', 'stl', 'blk', 'tov', 'pts', 'game_score', 'minus_plus'],
#       dtype='object')

# %%
df.dtypes
# Out:
# game            int64
# date           object
# age            object
# team           object
# opp            object
# result         object
# mp             object
# fg              int64
# fga             int64
# fgp           float64
# three           int64
# threeatt        int64
# threep        float64
# ft              int64
# fta             int64
# ftp           float64
# orb             int64
# drb             int64
# trb             int64
# ast             int64
# stl             int64
# blk             int64
# tov             int64
# pts             int64
# game_score    float64
# minus_plus      int64
# dtype: object

# %%
df.tail()
# Out:
#       game        date     age team  opp   result     mp  fg  fga    fgp  ...  \
# 1127    67  2018-03-13  33-073  CLE  PHO  W (+22)  33:13   7   14  0.500  ...
# 1128    68  2018-03-15  33-075  CLE  POR   L (-8)  41:05  15   25  0.600  ...
# 1129    69  2018-03-17  33-077  CLE  CHI   W (+5)  39:53  15   26  0.577  ...
# 1130    70  2018-03-19  33-079  CLE  MIL   W (+7)  40:01  16   29  0.552  ...
# 1131    71  2018-03-21  33-081  CLE  TOR   W (+3)  39:24  11   19  0.579  ...
#
#       orb  drb  trb  ast  stl  blk  tov  pts  game_score  minus_plus
# 1127    0   12   12   11    3    2    5   28        30.1          23
# 1128    0   14   14    6    2    3    6   35        26.4          -3
# 1129    1   12   13   12    1    2    6   33        27.5          -4
# 1130    5    7   12   10    2    1    6   40        33.4           4
# 1131    1    6    7   17    1    0    0   35        39.9          12
#
# [5 rows x 26 columns]

# %%
df['age']=df['age'].str.split('-').str[0]

# %%
df.describe()
# Out:
#               game           fg          fga          fgp        three  \
# count  1132.000000  1132.000000  1132.000000  1132.000000  1132.000000
# mean     38.385159     9.866608    19.585689     0.505467     1.409894
# std      22.038108     3.099422     4.868082     0.114112     1.396538
# min       1.000000     0.000000     5.000000     0.000000     0.000000
# 25%      19.000000     8.000000    16.000000     0.429000     0.000000
# 50%      38.000000    10.000000    20.000000     0.500000     1.000000
# 75%      57.000000    12.000000    23.000000     0.579000     2.000000
# max      81.000000    23.000000    36.000000     0.929000     8.000000
#
#           threeatt       threep           ft          fta          ftp  \
# count  1132.000000  1092.000000  1132.000000  1132.000000  1120.000000
# mean      4.103357     0.309266     6.005300     8.126325     0.734154
# std       2.346039     0.253228     3.449518     4.220171     0.185503
# ...

# %% [markdown]
# df_view=df[['age', 'team', 'opp', 'result', 'mp', 'fg', 'fga',
#        'fgp', 'three', 'threeatt', 'threep', 'ft', 'fta', 'ftp', 'orb', 'drb',
#         'ast', 'stl', 'blk', 'tov', 'pts', 'game_score']]

# %%
df_view=df.copy()

# %%
df_view.columns
# Out:
# Index(['game', 'date', 'age', 'team', 'opp', 'result', 'mp', 'fg', 'fga',
#        'fgp', 'three', 'threeatt', 'threep', 'ft', 'fta', 'ftp', 'orb', 'drb',
#        'trb', 'ast', 'stl', 'blk', 'tov', 'pts', 'game_score', 'minus_plus'],
#       dtype='object')

# %% [markdown]
# you can also drop a single or two more colunns using drop fuction

# %% [markdown]
# common sense for function always use () for access use[]

# %% [markdown]
# renaming the columns

# %%
df_view.rename(columns={'ft':'free throw'})
df_view.rename(columns={'age':'Age'})
# Out:
#       game        date Age team  opp   result     mp  fg  fga    fgp  ...  \
# 0        1  2003-10-29  18  CLE  SAC  L (-14)  42:00  12   20  0.600  ...
# 1        2  2003-10-30  18  CLE  PHO   L (-9)  41:00   8   17  0.471  ...
# 2        3  2003-11-01  18  CLE  POR  L (-19)  39:00   3   12  0.250  ...
# 3        4  2003-11-05  18  CLE  DEN   L (-4)  41:00   3   11  0.273  ...
# 4        5  2003-11-07  18  CLE  IND   L (-1)  44:00   8   18  0.444  ...
# ...    ...         ...  ..  ...  ...      ...    ...  ..  ...    ...  ...
# 1127    67  2018-03-13  33  CLE  PHO  W (+22)  33:13   7   14  0.500  ...
# 1128    68  2018-03-15  33  CLE  POR   L (-8)  41:05  15   25  0.600  ...
# 1129    69  2018-03-17  33  CLE  CHI   W (+5)  39:53  15   26  0.577  ...
# 1130    70  2018-03-19  33  CLE  MIL   W (+7)  40:01  16   29  0.552  ...
# 1131    71  2018-03-21  33  CLE  TOR   W (+3)  39:24  11   19  0.579  ...
#
#       orb  drb  trb  ast  stl  blk  tov  pts  game_score  minus_plus
# ...

# %%
df_view.rename(columns={'ft':'free throw', 'age':'Age'}, inplace=True)

# %% [markdown]
# Missing values initial step in the data cleaning process nad alaso find the duplicates this works by giving out true or false

# %%
df_view.isna().sum()
# Out:
# game           0
# date           0
# Age            0
# team           0
# opp            0
# result         0
# mp             0
# fg             0
# fga            0
# fgp            0
# three          0
# threeatt       0
# threep        40
# free throw     0
# fta            0
# ftp           12
# orb            0
# drb            0
# trb            0
# ast            0
# stl            0
# blk            0
# tov            0
# pts            0
# game_score     0
# minus_plus     0
# dtype: int64

# %%
#df_tt=df_view.loc[(df_view['age']>23) & (df_view['age']<30)]

# %%
df_view['result']=df_view['result'].str.split('(').str[0]

# %%
df_view.head()
# Out:
#    game        date Age team  opp result     mp  fg  fga    fgp  ...  orb  \
# 0     1  2003-10-29  18  CLE  SAC     L   42:00  12   20  0.600  ...    2
# 1     2  2003-10-30  18  CLE  PHO     L   41:00   8   17  0.471  ...    2
# 2     3  2003-11-01  18  CLE  POR     L   39:00   3   12  0.250  ...    0
# 3     4  2003-11-05  18  CLE  DEN     L   41:00   3   11  0.273  ...    2
# 4     5  2003-11-07  18  CLE  IND     L   44:00   8   18  0.444  ...    0
#
#    drb  trb  ast  stl  blk  tov  pts  game_score  minus_plus
# 0    4    6    9    4    0    2   25        24.7          -9
# 1   10   12    8    1    0    7   21        14.7          -3
# 2    4    4    6    2    0    2    8         5.0         -21
# 3    9   11    7    2    3    2    7        11.2          -3
# 4    5    5    3    0    0    7   23         9.0          -7
#
# [5 rows x 26 columns]

# %%
#df_view.drop(['reuslt'],axis=1)

# %% [markdown]
# ***Understanding the features :**
# histogram (to gauge the distibution )
# kde
# boxplot (to ubndertand about the outliers )

# %%
tpa=df_view['opp'].value_counts() \
    .head(10) \
    .plot(kind='bar',title='Most teams played against ')
tpa.set_xlabel('Teams')
tpa.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
fg=df_view['fg']\
    .plot(kind='kde',
          title='Field goal percenatge')

# %%
import seaborn as sns

# %%
sns.histplot(df_view['fg'],bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='fg', ylabel='Count'>

# %% [markdown]
# ** co relations between different features **
#
# Scatterplot
#
# heatmap co relation
#
# pairplot
#
# groupby comparison

# %%
#scatterplot
df_view.plot(kind='scatter',x='fg',
             y='game_score')

# concecntrate on stuff like positive co realtion , negative co relation 
# and also about the kine that is drawn to understand how strong the co relation is
# Out:
# <AxesSubplot:xlabel='fg', ylabel='game_score'>

# %%
sns.scatterplot(data=df_view,x='fg'
                ,y='game_score',
                hue='Age')
# hue is sexy now i can know at what age his fg looked real good
# Out:
# <AxesSubplot:xlabel='fg', ylabel='game_score'>

# %%
sns.pairplot(data=df_view,
             vars=['fg','pts','ast','threep'],
             hue='team')
plt.show()

# %%
ana_list=['fg','pts','ast','threep']

# %%
df_corr=df_view[ana_list].dropna().corr()

# %%
sns.heatmap(df_corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ** Final step is asking queations about the data **

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pd=pd.read_excel(r'C:/Users/user/OneDrive/Desktop/Medals.xlsx')
#for having desired index always use index_col='user_defined_col_name'
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
p_d.head(5)
# Out:
#    Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0     1    United States of America    39      41      33    113
# 1     2  People's Republic of China    38      32      18     88
# 2     3                       Japan    27      14      17     58
# 3     4               Great Britain    22      21      22     65
# 4     5                         ROC    20      28      23     71
#
#    Rank by Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3

# %%
p_d['Total'].mean()
# Out:
# 11.612903225806452

# %%
p_d.set_index('Rank',inplace=True)

# %% [markdown]
# weighted means (the best exmaple would be salary of different employeeas at a company - a guy with 25 year of experience cant be equal to an intern so need to add some weights the salary cap )

# %%
import numpy as np

# %%
tw=(p_d['Gold']).mean()+(p_d['Silver']).mean()+(p_d['Bronze']).mean()

# %%
tw
# Out:
# 11.612903225806452

# %%
#p_d.drop(labels='gold',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 p_d.drop(labels='gold',axis=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:4906, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
p_d['g']=p_d['Gold']*2
p_d['s']=p_d['Silver']*1.5
p_d['b']=p_d['Bronze']*1

# %%
p_d['t']=p_d['g']+p_d['s']+p_d['b']

# %%
p_d['t'].mean()

# %% [markdown]
# robust metrics are the metrics not susceptible to outliers
# use of trimmed mean what happens is X % of the data in the top part or the
# part is removed so that the ouliers are thrown out .

# %%
from scipy.stats import

# %%
p_d.loc[(p_d['Total']<10) & (p_d['Bronze']>2)]
# loc fuction du bread and buttet is your df.loc['index','column']=78 
# will return user defined index and will assign value 78 for it

# %%
p_d.loc[[67,68],['Gold','Bronze','Team/NOC']]

# %%
p_d.loc[[67,68],'Total']=43

# %%
p_d.loc[(p_d['Total']==6),'Silver']=7

# %%
p_d.loc[30]

# %%
# uses of medain as it has no influence of outliers on it because all the 
#data points are arranged in ascending order the middle value gives an 
#absolute idea about the central tendecy 
#for example salary in a company 1,2,3,4,5,6,8,100
# if mean was taken then then it would be 14 would not make any sense

# %%
#Estimates of varaiablity greater the variance greater the information and 
#better the preidctability

# %% [markdown]
# ## Estimates of vairance
# The deviations are the measure of how far the values are from the actual value

# %%
from statistics import variance

# %%
variance(p_d['gold'])
#p_d['Gold'].std()

# %%
import seaborn as sns

# %%
q1,q2=np.percentile(p_d['Gold'],[75,50])

# %%
iqr=q1-q2
iqr

# %%
p=sns.load_dataset('penguins')

# %%
sns.histplot(data=p,y='flipper_length_mm',hue="species",multiple="stack")

# %%
p_d.rename(columns={'Team/NOC':'team'})
# Out:
#                             team  Gold  Silver  Bronze  Total  Rank by Total  \
# Rank
# 1       United States of America    39      41      33    113              1
# 2     People's Republic of China    38      32      18     88              2
# 3                          Japan    27      14      17     58              5
# 4                  Great Britain    22      21      22     65              4
# 5                            ROC    20      28      23     71              3
# ...                          ...   ...     ...     ...    ...            ...
# 86                         Ghana     0       0       1      1             77
# 86                       Grenada     0       0       1      1             77
# 86                        Kuwait     0       0       1      1             77
# 86           Republic of Moldova     0       0       1      1             77
# 86          Syrian Arab Republic     0       0       1      1             77
#
#       gold   g     s   b      t
# ...

# %%
## binary and catergorical values analysis

# %%
ax=p_d.iloc[:5].plot.bar(x="Team/NOC",y="Gold")
ax
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ax=p_d.iloc[:5].plot.bar(x="Team/NOC",y="Gold")
#       2 ax
#
# NameError: name 'p_d' is not defined

# %%
import pandas as pd

# %%
data = {'nigga':[1,2,3,4]
        ,'pg':[34,56,67,87]
        ,'team':['cle','nig','afl','saint_kilda']}
df=pd.DataFrame(data)

# %%
df.loc[2]
# Out:
# nigga              3
# pg                67
# team     challengers
# Name: 2, dtype: object

# %%
import seaborn as sns

# %%
pg=sns.load_dataset("penguins")

# %%
sns.histplot(data=pg['species'],)
# Out:
# <AxesSubplot:xlabel='species', ylabel='Count'>

# %%
from random import sample
import random as random

# %%
pg1=pg.sample(n=100)

# %%
pg1.head()
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 135     Adelie   Dream            41.1           17.5              190.0
# 284     Gentoo  Biscoe            45.8           14.2              219.0
# 160  Chinstrap   Dream            46.0           18.9              195.0
# 103     Adelie  Biscoe            37.8           20.0              190.0
# 137     Adelie   Dream            40.2           20.1              200.0
#
#      body_mass_g     sex
# 135       3900.0    Male
# 284       4700.0  Female
# 160       4150.0  Female
# 103       4250.0    Male
# 137       3975.0    Male

# %%
sns.scatterplot(data=pg1,x='bill_length_mm',y='flipper_length_mm',hue='island')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# sampling bias : the bias or favorism that exists because of how the data is selected
# data snooping : you are searching for a particular data which is not adviced
# vast search effect :The more variables you have, the easier it becomes to 'oversearch' and identify (false) patterns among them
# Regression by mean : when you get a outlier always check is the values after it are followed by the mean if they are then you will have a clear picture if its an outlier.
# if the sampled data that you took is a good representaion of the population then it will follow a normal distribution , a bell shaped curve .

# %%
dg={'location':['mys','bang','goa'],
    'age':[67,98,67] ,
    'lang':['kan','hin','goa']}

# %%
import pandas as pd

# %%
df=pd.DataFrame(dg)

# %%
df.loc[(df['age']>90)]
# Out:
#   location  age lang
# 1     bang   98   mi

# %%
pg.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pg.shape
#
# NameError: name 'pg' is not defined

# %%
sample1=[10,300,50]
for i in sample1:
    s=[]
    for j in range(1000):
        s.append(pg['bill_length_mm'].sample(i).mean())
    plt.hist(s)

# %%
pg['bill_length_mm'].sem()
# Out:
# 0.29522047628517617

# %%
pg1=pg.sample(10)

# %%
pg1['bill_length_mm'].sem()
# Out:
# 1.8331144650499347
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
sns.histplot(data=pg,x=pg['bill_length_mm'],hue=pg['sex'])
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
pg_m=pg.groupby('sex')

# %%
pgmp=pg_m.get_group('Male')

# %%
sns.histplot(data=pgmp['bill_length_mm'])
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
import pandas as pd
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt

# %%
df_lab=pd.read_csv("C:/Users/user/OneDrive/Desktop/rate.csv")
